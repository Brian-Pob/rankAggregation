# %%
import pandas as pd

# %%
result = pd.read_csv(r"fig_8d_result.csv",header=None)

# %%
x = result[0].to_list()
y = result[1].to_list()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


plt.plot(x,y)


plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Number of ranks',fontweight='bold',fontsize=20)

#plt.xticks([2000,4000,6000,8000,10000], ['2000','4000','6000','8000','10000'])
#plt.yticks([0,1], ['0','0.1'])
plt.legend(["AlgRAPF"],fontsize=18,loc='upper left')
#fig.savefig("figure_ballot_change_normal_data/AlgCartOpt_vary_c.png", bbox_inches='tight', dpi=480)
plt.show()
