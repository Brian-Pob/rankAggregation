# %%
import pandas as pd

# %%
result = pd.read_csv(r"fig_5a_result.csv",header=None)

# %%
x = result[0].to_list()
x
# Out:
# [1000, 250000, 500000, 750000, 1000000]

# %%
y = result[1].to_list()
y
# Out:
# [0.0014105999999999,
#  0.4005463999999961,
#  0.8632941999999844,
#  1.2319966000000022,
#  2.326805700000022]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


plt.plot(x,y)


plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1000,500000,1000000], ['1k','500k','1000k'])
# #plt.yticks([0,5], ['0','5'])
plt.legend(["GrBinaryIPF"],fontsize=18,loc='upper left')
#fig.savefig("figure_ballot_change_normal_data/AlgCartOpt_vary_c.png", bbox_inches='tight', dpi=480)
plt.show()
