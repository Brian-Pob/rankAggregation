# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,20,50,100,1000]
y = [1.018,2.277,5.887,9.924,81.62]


z = [1.3663,2.79367,6.8835,13.5126,111.1942]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
#plt.yticks([1000,2000,3000,4000], ['1000','2000','3000',''])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/Alg1AttBOpt_vs_Alg1AttMOpt_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,50,100,200]
y = [0.7296,0.86,0.94,0.9833]

z = [0.85,0.90,1.01,1.232]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

#plt.xticks([10,500,1000], ['10k','500k','1000k'])
plt.yticks([0,3], ['0','3'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/Alg1AttBOpt_vs_Alg1AttMOpt_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,100,200,300,400,500,1000]
#y = [0.7296,0.86,0.94,0.9833]

z = [0.03,1.8,8.75,21.37,44.12,82.87,617.88]


#plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

#plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
#plt.yticks([1000,2000,3000,4000], ['1000','2000','3000',''])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/Approx_multi2_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [100,500,1000]
y = [0.8,0.86,1.07]

z = [0.95,1.0,1.1]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)

plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
plt.yticks([0,3], ['0','3'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/Alg1AttBOpt_vs_Alg1AttMOpt_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [15,50,100,150,200]
y = [1.84,1.95,3.06,2.53,1.87]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

#plt.xticks([100,500,1000], ['100k','500k','1000k'])
plt.yticks([0,5], ['0','5'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/Approx_multi2_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,10,100,500,1000]
y = [2.04,1.99,2.15,2.18,2.06]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)

plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
plt.yticks([0,5], ['0','5'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/Approx_multi2_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [4,5,6]
y = [0.32,3.34,76.39]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying c',fontweight='bold',fontsize=20)

plt.xticks([4,5,6], ['4','5','6'])
#plt.yticks([0,5], ['0','5'])
plt.legend(["AlgCartOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_new/AlgCartOpt_vary_c.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
#normal data plot start

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,250,500,750,1000]
y = [0.002,2.76,5.81,8.51,9.46]


z = [0.009,2.894,6.02,7.70,9.97]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
#plt.yticks([1000,2000,3000,4000], ['1000','2000','3000',''])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,250,500,750,1000]
y = [0.033,0.134,0.126,0.126,0.118]


z = [0.022,0.117,0.177,0.233,0.181]

plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)


plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
plt.yticks([0,1,2], ['0','1','2'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,50,100,200]
y = [0.09,0.292,0.195,0.121]

z = [0.11,0.129,0.109,0.121]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

plt.xticks([10,50,100,150,200], ['10','50','100','150','200'])
plt.yticks([0,1,2], ['0','1','2'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1000,2500,5000,7500,10000]
y = [13.2,26.65,40.49,65.98,136.275]

#z = []


#plt.plot(x,y)
plt.plot(x,y)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1000,2500,5000,7500,10000], ['1k','2.5k','5k','7.5k','10k'])
#plt.yticks([1000,2000,3000,4000], ['1000','2000','3000',''])
plt.legend(["Alg2AttApx"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [4.263,50.58,75.18,100.44,115.55]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['1k','25k','50k','75k','100k'])
#plt.yticks([0,5], ['0','5'])
plt.legend(['Alg2AttApx'],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
sum lv =  100000 len lc =  10000
6 22
time required =  41.959952599999994
        sum lv =  100000 len lc =  10000
33 19
time required =  87.52991929999999
sum lv =  100000 len lc =  10000
14 19
time required =  82.4081002
sum lv =  100000 len lc =  10000
14 19
time required =  87.00052649999998
sum lv =  100000 len lc =  10000
14 19
time required =  89.17446610000002

Process finished with exit code 0

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,50,100,150,200]
y = [41.95,87.529,83.4054,87.00,89.1744]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

plt.xticks([10,50,100,150,200], ['10','50','100','150','200'])
plt.yticks([0,25,50,75,100], ['0','25','50','75','100'])
plt.legend(["Alg2AttApx"],fontsize=18,loc='lower left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
sum lv =  1000 len lc =  10000
24 2
time required =  10.943006400000002
sum lv =  25000 len lc =  10000
34 8
time required =  46.2479813
sum lv =  50000 len lc =  10000
34 12
time required =  71.8581091
sum lv =  75000 len lc =  10000
40 16
time required =  89.04318119999999
sum lv =  100000 len lc =  10000
58 20
time required =  93.7920622

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [10.94,44.24,67.85,85.04,94.79]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['1k','25k','50k','75k','100k'])
plt.yticks([0,25,50,75,100], ['0','25','50','75','100'])
plt.legend(['Alg2AttApx'],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [12,20,38,50,96]

#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['1k','25k','50k','75k','100k'])
plt.yticks([0,25,50,75,100], ['0','25','50','75','100'])
plt.legend(['Alg2AttApx'],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
sum lv =  100000 len lc =  1000
53 118
time required =  12.9242907
sum lv =  100000 len lc =  2500
48 54
time required =  24.241700699999996
sum lv =  100000 len lc =  5000
73 32
time required =  42.5575084
sum lv =  100000 len lc =  7500
79 23
time required =  78.0906761
sum lv =  100000 len lc =  10000
48 20
time required =  96.16634970000001

Process finished with exit code 0

# %%
C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
sum lv =  1000 len lc =  10000
24 2
time required =  10.943006400000002
sum lv =  25000 len lc =  10000
34 8
time required =  46.2479813
sum lv =  50000 len lc =  10000
34 12
time required =  71.8581091
sum lv =  75000 len lc =  10000
40 16
time required =  89.04318119999999
sum lv =  100000 len lc =  10000
58 20
time required =  93.7920622

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1000,2000,3000,4000,5000]
y = [0.14,0.13,0.13,0.14,0.14]


z = [0.26,0.32,0.20,0.16,0.16]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying sd',fontweight='bold',fontsize=20)

plt.xticks([1000,2000,3000,4000,5000], ['1k','2k','3k','4k','5k'])
plt.yticks([0,1], ['0','1'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_sd.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [3000,4000,5000,6000,7000]
y = [0.10,0.08,0.09,0.08,0.08]


z = [0.17,0.16,0.15,0.19,0.21]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying mean',fontweight='bold',fontsize=20)

plt.xticks([3000,4000,5000,6000,7000], ['3k','4k','5k','6k','7k'])
plt.yticks([0,1], ['0','1'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_mn.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
49
time required =  0.006870699999999896
320
time required =  7.941038600000001
157
time required =  16.3835245
71
time required =  22.299328700000004
107
time required =  30.808862399999995


C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
22
time required =  0.08094479999999993
2126
time required =  0.39448969999999994
20648
time required =  0.4966381000000002
40857
time required =  0.4309784000000001
85646
time required =  0.48968750000000005

Process finished with exit code 0

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,250,500,750,1000]
y = [0.002,2.76,5.81,8.51,9.46]


z = [0.006,7.94,16.38,22.29,30.80]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
#plt.yticks([1000,2000,3000,4000], ['1000','2000','3000',''])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_n_l=30.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,250,500,750,1000]
y = [0.033,0.134,0.126,0.126,0.118]


z = [0.08,0.39,0.49,0.43,0.48]

plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)


plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
plt.yticks([0,1,2], ['0','1','2'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_m_l=30.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,50,100,200]
y = [0.09,0.292,0.195,0.121]

z = [0.11,0.129,0.109,0.121]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

plt.xticks([10,50,100,150,200], ['10','50','100','150','200'])
plt.yticks([0,1,2], ['0','1','2'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
k = 20
running time for single multi =  0.027795610000000005  for n,m =  1000 10000000
running time for single multi =  8.327122870000002  for n,m =  250000 10000000
running time for single multi =  17.671944219999993  for n,m =  500000 10000000
running time for single multi =  28.21251324000001  for n,m =  750000 10000000
running time for single multi =  36.86325012  for n,m =  1000000 10000000

# %%
k = 15
running time for single multi =  0.02652263000000001  for n,m =  1000 10000000
running time for single multi =  6.846885880000002  for n,m =  250000 10000000
running time for single multi =  12.799077549999996  for n,m =  500000 10000000
running time for single multi =  22.56467811  for n,m =  750000 10000000
running time for single multi =  27.734067910000014  for n,m =  1000000 10000000

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,250,500,750,1000]
y = [0.003,0.40,1.26,1.83,1.98]

z = [0.02,6.84,12.79,22.56,27.73]
#z = [ 0.02,8.32,17.67,28.21,36.86]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
plt.yticks([0,10,20,30,40], ['0','10','20','30','40'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,250,500,750,1000]
#y = [0.33,0.29,0.20,0.25,0.18]
y = [0.36,0.29,0.19,0.24,0.18]

#z = [0.39,2.01,1.64,2.93,2.44]
z = [0.37,1.98,1.599,2.48,2.60]
plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)


plt.xticks([1,250,500,750,1000], ['1k','250k','500k','750k','1000k'])
plt.yticks([0,3,6], ['0','3','6'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,50,100,200]
y = [0.21,0.22,0.27,0.21]

z = [2.62,2.87,3.20,2.62]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

plt.xticks([10,50,100,150,200], ['10','50','100','150','200'])
plt.yticks([0,3,6], ['0','3','6'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
running time for single binary =  0.15022663999999394  for n,m =  100000 10000000
running time for single multi =  2.6852331399999967  for n,m =  100000 10000000
running time for single binary =  0.1988389199999915  for n,m =  100000 10000000
running time for single multi =  2.8059291799999984  for n,m =  100000 10000000
running time for single binary =  0.2871245600000066  for n,m =  100000 10000000
running time for single multi =  3.238464560000034  for n,m =  100000 10000000
running time for single binary =  0.177418479999983  for n,m =  100000 10000000
running time for single multi =  3.4996749200000523  for n,m =  100000 10000000
running time for single binary =  0.1655159200000071  for n,m =  100000 10000000
running time for single multi =  3.58920136510215301  for n,m =  100000 10000000

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [0.15,0.19,0.28,0.17,0.165]


z = [2.68,2.80,3.23,3.49,3.58]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying mean',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['1k','25k','50k','75k','100k'])
plt.yticks([0,3,6], ['0','3','6'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_mn.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
running time for single binary =  0.28317390000000275  for n,m =  100000 10000000
running time for single multi =  2.678513359999994  for n,m =  100000 10000000
running time for single binary =  0.24576047999997855  for n,m =  100000 10000000
running time for single multi =  3.4180806399999826  for n,m =  100000 10000000
running time for single binary =  0.4326911599999903  for n,m =  100000 10000000
running time for single multi =  3.4120793999999934  for n,m =  100000 10000000
running time for single binary =  0.22435195999998997  for n,m =  100000 10000000
running time for single multi =  3.0347979199999826  for n,m =  100000 10000000
running time for single binary =  0.22459782000000814  for n,m =  100000 10000000
running time for single multi =  2.6568682999999966  for n,m =  100000 10000000

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [0.28,0.24,0.43,0.22,0.22]


z = [2.67,3.418,3.412,3.03,2.65]


plt.plot(x,y)
plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying sd',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['1k','25k','50k','75k','100k'])
plt.yticks([0,3,6], ['0','3','6'])
plt.legend(["Alg1AttBOpt","Alg1AttMOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Alg1AttBOpt_vs_Alg1AttMOpt_vary_sd.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
finish
time required for att2 =  16.8085864  n,m =  1000 100000
finish
time required for att2 =  34.27573410000001  n,m =  2500 100000
finish
time required for att2 =  59.8283482  n,m =  5000 100000
finish
time required for att2 =  155.98613730000002  n,m =  7500 100000
finish
time required for att2 =  230.20949329999996  n,m =  10000 100000

Process finished with exit code 0

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [16.80,34.27,59.82,155.98,230.209]



plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['0.1k','2.5k','5k','7.5k','10k'])
#plt.yticks([0,25,50,75,100], ['0','25','50','75','100'])
plt.legend(['Alg2AttApx'],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_n.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
C:\Users\mouin\Anaconda3\python.exe D:/ballotchangeproblem/code/new_git_code/BallotChange-main/BallotChange-main/main.py
finish
time required for att2 =  1.7331812999999998  n,m =  1000 1000
finish
time required for att2 =  2.671315  n,m =  1000 2500
finish
time required for att2 =  3.1806355  n,m =  1000 5000
finish
time required for att2 =  5.0624113999999985  n,m =  1000 7500
finish
time required for att2 =  5.7789543000000005  n,m =  1000 10000

Process finished with exit code 0

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [1,25,50,75,100]
y = [1.73,2.67,3.18,5.06,5.77]



plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying m',fontweight='bold',fontsize=20)

plt.xticks([1,25,50,75,100], ['0.1k','2.5k','5k','7.5k','10k'])
#plt.yticks([0,25,50,75,100], ['0','25','50','75','100'])
plt.legend(['Alg2AttApx'],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_m.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [10,50,100,150,200]
y = [6.60,6.60,6.003,11.48,9.51]



plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying k',fontweight='bold',fontsize=20)

plt.xticks([10,50,100,150,200], ['10','50','100','150','200'])
plt.yticks([0,10,20], ['0','10','20'])
plt.legend(['Alg2AttApx'],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/Approx_multi2_vary_k.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
fig, ax = plt.subplots(nrows=1, ncols=1)


x = [5,6,7]
y = [0.04,2,74]
#z = [0.95,1.0,1.1]


plt.plot(x,y)
#plt.plot(x,z)
# create an index for each tick position

plt.ylabel('Time in Seconds',fontweight='bold',fontsize=20)
plt.xlabel('Varying n',fontweight='bold',fontsize=20)

plt.xticks([5,6,7], ['5','6','7'])
#plt.yticks([0,5], ['0','5'])
plt.legend(["AlgCartOpt"],fontsize=18,loc='upper left')
fig.savefig("figure_ballot_change_normal_data/AlgCartOpt_vary_c.png", bbox_inches='tight', dpi=480)
plt.show()

# %%
pow(5,8)
# Out:
# 390625
